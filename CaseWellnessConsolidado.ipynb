# %% [markdown]
# <a href="https://colab.research.google.com/github/karenQuiroga88/python_cases/blob/main/CaseWellnessConsolidado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Case: Screen Time vs Mental Wellness Survey
# Obetivo:
#
# *  Analisar de que forma as atividades diárias — influenciam a produtividade de profissionais em diferentes regimes de trabalho: híbrido, presencial e remoto.
#
# 1.   Média de produtividade por regime de trabalho
# 2.   Analisar a relação entre o tempo de prática de exercícios físicos e o regime de trabalho adotado.
# 3.  Entender a relação entre leisure_screen_hours e o stress_level entre os diferentes regimes dee trabalho

# %% [markdown]
# ###1: Importar bibliotecas e montar acesso google drive

# %%
# --- Instalar e importar bibliotecas necessárias ---
from google.colab import drive
from IPython.display import display
import pandas as pd
import os
import plotly.express as px

# --- 1. Montar o Google Drive ---
drive.mount('/content/drive', force_remount=True)

# --- 2. Definir o caminho da pasta no Drive ---
# Substitua "Colab Notebooks" pelo nome exato da pasta onde está o arquivo
pasta = '/content/drive/MyDrive/Colab Notebooks'
arquivo01 = 'resultado_consolidado.csv'
caminhoCompleto01 = os.path.join(pasta, arquivo01)

aqurvivo02= 'raw.csv'
caminhoCompleto02 = os.path.join(pasta, aqurvivo02)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Lendo os arquivos

# %%
### raw data, arquivo tratado na v1.

df_raw = pd.read_csv(caminhoCompleto02)
print("✅ Dados carregados com sucesso!")
print(display(df_raw.head(10)))
# Out:
# ✅ Dados carregados com sucesso!
#   user_id  age            gender     occupation  work_mode  screen_time_hours  \
# 0   U0001   33            Female       Employed     Remote              10.79
# 1   U0002   28            Female       Employed  In-person               7.40
# 2   U0003   35            Female       Employed     Hybrid               9.78
# 3   U0004   42              Male       Employed     Hybrid              11.13
# 4   U0005   28              Male        Student     Remote              13.22
# 5   U0006   28  Non-binary/Other  Self-employed     Hybrid               9.83
# 6   U0007   42  Non-binary/Other        Retired     Remote               6.02
# 7   U0008   36              Male       Employed  In-person               6.21
# 8   U0009   26              Male        Student  In-person               6.28
# 9   U0010   34              Male       Employed     Hybrid               9.37
#
#    work_screen_hours  leisure_screen_hours  sleep_hours  sleep_quality_1_5  \
# 0               5.44                  5.35         6.63                  1
# 1               0.37                  7.03         8.05                  3
# 2               1.09                  8.69         6.48                  1
# 3               0.56                 10.57         6.89                  1
# 4               4.09                  9.13         5.79                  1
# 5               0.53                  9.30         7.19                  1
# 6               2.82                  3.20         7.44                  2
# 7               0.75                  5.46         6.78                  2
# 8               0.67                  5.61         8.48                  4
# 9               0.84                  8.53         7.78                  2
#
#    stress_level_0_10  productivity_0_100  exercise_minutes_per_week  \
# 0                9.3                44.7                        127
# 1                5.7                78.0                         74
# 2                9.1                51.8                         67
# 3               10.0                37.0                          0
# 4               10.0                38.5                        143
# 5               10.0                44.0                         71
# 6                6.1                64.8                        141
# 7                5.4                87.0                         51
# 8                1.6                91.7                        149
# 9               10.0                42.2                         50
#
#    social_hours_per_week  mental_wellness_index_0_100
# 0                    0.7                          9.3
# 1                    2.1                         56.2
# 2                    8.0                          3.6
# 3                    5.7                          0.0
# 4                   10.1                          0.0
# 5                   10.3                          5.0
# 6                    4.7                         43.7
# 7                   18.7                         54.3
# 8                   10.1                         86.8
# 9                   12.7                         10.7
# None

# %%
### métricas consolidadas, arquivo tratado na v1.
df = pd.read_csv(caminhoCompleto01)
print("✅ Dados carregados com sucesso!")
print(display(df.head(10)))
# Out:
# ✅ Dados carregados com sucesso!
#   occupation  work_mode            gender   age  screen_time_hours  \
# 0   Employed     Hybrid            Female  29.0                9.0
# 1   Employed     Hybrid              Male  30.0                9.0
# 2   Employed     Hybrid  Non-binary/Other  34.0                8.0
# 3   Employed  In-person            Female  28.0                9.0
# 4   Employed  In-person              Male  25.0                8.0
# 5   Employed  In-person  Non-binary/Other  47.0                2.0
# 6   Employed     Remote            Female  30.0                9.0
# 7   Employed     Remote              Male  31.0                9.0
# 8    Retired     Hybrid            Female  24.0                5.0
# 9    Retired     Hybrid              Male  41.0                1.0
#
#    work_screen_hours  leisure_screen_hours  sleep_hours  \
# 0                1.0                   8.0          7.0
# 1                1.0                   8.0          7.0
# 2                1.0                   8.0          7.0
# 3                1.0                   7.0          7.0
# 4                1.0                   7.0          7.0
# 5                0.0                   2.0          6.0
# 6                4.0                   6.0          7.0
# 7                3.0                   5.0          7.0
# 8                1.0                   4.0          7.0
# 9                0.0                   1.0          8.0
#
#    exercise_minutes_per_week  stress_level_0_10  productivity_0_100  \
# 0                       96.0                8.0                52.0
# 1                       97.0                9.0                53.0
# 2                      131.0                9.0                49.0
# 3                      124.0                8.0                54.0
# 4                       90.0                7.0                56.0
# 5                      132.0                7.0                66.0
# 6                      100.0                9.0                48.0
# 7                      106.0               10.0                49.0
# 8                      134.0                7.0                69.0
# 9                      124.0                0.0                97.0
#
#    social_hours_per_week  mental_wellness_index_0_100
# 0                    7.0                         19.0
# 1                    9.0                         16.0
# 2                    6.0                         24.0
# 3                    8.0                         22.0
# 4                    9.0                         17.0
# 5                   16.0                         28.0
# 6                    8.0                          9.0
# 7                    7.0                         11.0
# 8                   13.0                         30.0
# 9                   13.0                         84.0
# None

# %% [markdown]
# ### Gráfico: Média de Produtividade por Regime de Trabalho

# %%
# --- 4. Cálculo da média de produtividade ---
mediaProdutividade = (
    df_raw[df_raw['occupation'] == 'Employed']
    .groupby(['work_mode'])['productivity_0_100']
    .median()
    .reset_index()
)

##print("\n📊 Média de produtividade por tipo de trabalho:")
##print(mediaProdutividade)

grafico01 = px.bar(
    mediaProdutividade,
    x='work_mode',
    y='productivity_0_100',
    color='work_mode',
    title='Rank com a Média de Produtividade por Regime de Trabalho',
    text_auto=True,
    range_y=[0, 100]
)
grafico01.show()

mediaProdutividadeGenero = (
    df[df['occupation']=='Employed']
    .groupby(['work_mode','gender'])['productivity_0_100']
    .median()
    .reset_index()
)

grafico002 = px.line(
    mediaProdutividadeGenero,
    x='work_mode',
    y='productivity_0_100',
    color='gender',
    title='Média com o Rank de Produtividade por Gênero',
    markers=True,   # adiciona pontos nas linhas
    text='productivity_0_100',
    range_y=[0, 100]
)
grafico002.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e1425147-0ce5-4c02-a2d6-0eecf8a28eb3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e1425147-0ce5-4c02-a2d6-0eecf8a28eb3")) {                    Plotly.newPlot(                        "e1425147-0ce5-4c02-a2d6-0eecf8a28eb3",                        [{"alignmentgroup":"True","hovertemplate":"work_mode=%{x}\u003cbr\u003eproductivity_0_100=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hybrid","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Hybrid","offsetgroup":"Hybrid","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Hybrid"],"xaxis":"x","y":[52.2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"work_mode=%{x}\u003cbr\u003eproductivity_0_100=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"In-person","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"In-person","offsetgroup":"In-person","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["In-person"],"xaxis":"x","y":[55.3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"work_mode=%{x}\u003cbr\u003eproductivity_0_100=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Remote","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Remote","offsetgroup":"Remote","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Remote"],"xaxis":"x","y":[48.45],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.33 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="34d6b042-0405-4cdb-9043-8ab890961479" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34d6b042-0405-4cdb-9043-8ab890961479")) {                    Plotly.newPlot(                        "34d6b042-0405-4cdb-9043-8ab890961479",                        [{"hovertemplate":"gender=Female\u003cbr\u003ework_mode=%{x}\u003cbr\u003eproductivity_0_100=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Female","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"Female","orientation":"v","showlegend":true,"text":[52.0,54.0,48.0],"x":["Hybrid","In-person","Remote"],"xaxis":"x","y":[52.0,54.0,48.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"gender=Male\u003cbr\u003ework_mode=%{x}\u003cbr\u003eproductivity_0_100=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Male","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"Male","orientation":"v","showlegend":true,"text":[53.0,56.0,49.0],"x":["Hybrid","In-person","Remote"],"xaxis":"x","y":[53.0,56.0,49.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"gender=Non-binary\u002fOther\u003cbr\u003ework_mode=%{x}\u003cbr\u003eproductivity_0_100=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Non-binary\u002fOther","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"Non-binary\u002fOther","orientation":"v","showlegend":true,"text":[49.0,66.0],"x":["Hybrid","In-person"],"xaxis":"x","y":[49.0,66.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surfa ...

# %%
# --- 5. Analisar a relação entre o tempo de prática de exercícios físicos e o rank de produtividade
mediaExercicio = (
    df_raw[df_raw['occupation'] == 'Employed']
    .groupby(['work_mode'])['exercise_minutes_per_week']
    .median()
    .reset_index()
)

##print("\n📊 Média de produtividade por tipo de trabalho:")
##print(mediaProdutividade)

# Gráfico interativo com Plotly ---
grafico03 = px.bar(
    mediaExercicio,
    x='work_mode',
    y='exercise_minutes_per_week',
    title='Média de Exercício Físico Por Regime de Trabalho',
    text_auto=True,
    color='work_mode'
)

grafico03.show()

mediaProdutividade = (
    df_raw[df_raw['occupation'] == 'Employed']
    .groupby(['work_mode'])['productivity_0_100']
    .median()
    .reset_index()
)

grafico04 = px.bar(
    mediaProdutividade,
    x='work_mode',
    y='productivity_0_100',
    title='Rank de Produtividade Por Regime de Trabalho',
    text_auto=True,
    color='work_mode',
    range_y=[0, 100]
)

grafico04.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="db9953ec-71c8-4444-9e1d-f7e074772550" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db9953ec-71c8-4444-9e1d-f7e074772550")) {                    Plotly.newPlot(                        "db9953ec-71c8-4444-9e1d-f7e074772550",                        [{"alignmentgroup":"True","hovertemplate":"work_mode=%{x}\u003cbr\u003eexercise_minutes_per_week=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hybrid","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Hybrid","offsetgroup":"Hybrid","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Hybrid"],"xaxis":"x","y":[96.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"work_mode=%{x}\u003cbr\u003eexercise_minutes_per_week=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"In-person","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"In-person","offsetgroup":"In-person","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["In-person"],"xaxis":"x","y":[106.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"work_mode=%{x}\u003cbr\u003eexercise_minutes_per_week=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Remote","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Remote","offsetgroup":"Remote","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Remote"],"xaxis":"x","y":[102.5],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222222 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b621b66b-f6a9-4071-a3fb-662daa49ec63" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b621b66b-f6a9-4071-a3fb-662daa49ec63")) {                    Plotly.newPlot(                        "b621b66b-f6a9-4071-a3fb-662daa49ec63",                        [{"alignmentgroup":"True","hovertemplate":"work_mode=%{x}\u003cbr\u003eproductivity_0_100=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hybrid","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Hybrid","offsetgroup":"Hybrid","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Hybrid"],"xaxis":"x","y":[52.2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"work_mode=%{x}\u003cbr\u003eproductivity_0_100=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"In-person","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"In-person","offsetgroup":"In-person","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["In-person"],"xaxis":"x","y":[55.3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"work_mode=%{x}\u003cbr\u003eproductivity_0_100=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Remote","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Remote","offsetgroup":"Remote","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Remote"],"xaxis":"x","y":[48.45],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.33 ...

# %%
# --- 6. Correlação da prática de exercício fisico com a saude mental por regime de trabalho adotado

df_saudeMental = df_raw[df_raw['occupation'] == 'Employed'][[
    'user_id', 'work_mode', 'exercise_minutes_per_week', 'mental_wellness_index_0_100'
]]

graficoSaudeMental = px.scatter(
    df_saudeMental,
    x='exercise_minutes_per_week',
    y='mental_wellness_index_0_100',
    ##color='work_mode',            # Mantém cores diferenciadas (opcional)
    hover_data=['user_id'],
    facet_col='work_mode',        # Cria um painel separado para cada work_mode
    trendline='ols',              # adiciona linha de tendência linear
    title='Exercício x Bem-estar Mental por Usuário',
    range_y=[0,100]
)

graficoSaudeMental.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="08f2c756-6f85-4622-b49d-47ea5d302de5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("08f2c756-6f85-4622-b49d-47ea5d302de5")) {                    Plotly.newPlot(                        "08f2c756-6f85-4622-b49d-47ea5d302de5",                        [{"customdata":[["U0001"],["U0014"],["U0024"],["U0036"],["U0040"],["U0043"],["U0044"],["U0055"],["U0062"],["U0065"],["U0066"],["U0067"],["U0076"],["U0092"],["U0110"],["U0116"],["U0120"],["U0133"],["U0137"],["U0140"],["U0167"],["U0168"],["U0188"],["U0189"],["U0190"],["U0193"],["U0213"],["U0216"],["U0229"],["U0230"],["U0242